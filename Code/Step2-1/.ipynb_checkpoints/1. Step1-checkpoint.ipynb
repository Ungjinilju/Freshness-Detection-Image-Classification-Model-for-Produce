# %% [markdown]
# # Guide
# ## Data
# [[Google Drive] /Data/Initial/Step2-1.zip](https://drive.google.com/file/d/1IUC0l3A54auk_K-vvc8nysB12g5Fx3D3/view?usp=sharing)
# ## Code
# In [3] `base_dir` : 실제 데이터 경로로 변경 필요
#
# ---

# %% [markdown]
# # Step1 Model
# [[Google Drive]/Code/Step1/6.Change_Conv2D_Dense.ipynb](https://drive.google.com/file/d/15Jwhm75pg7PJAmETxAXB5cAfI_rSpNy8/view?usp=sharing)
#
# ## Alternation
# 2개의 클래스 분류 → 6개의 클래스 분류
# ⇒ 마지막 layer의 노드 수, activation, 손실 함수 변경

# %%
from tensorflow import keras
from tensorflow.keras import layers, optimizers
import os
# Out:
# 2024-11-22 15:08:58.255545: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
image_size = (400, 400)
batch_size = 32

# %% [markdown]
# ### Data 변경

# %%
# 데이터셋 로드
from tensorflow.keras.utils import image_dataset_from_directory

# 실제 데이터의 경로로 변경 필요
base_dir = "/tf/Fixed_Data/Data_Initial/Step2-1"  # Data_Initial/Step1

train_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'train'),
    image_size=image_size,
    batch_size=batch_size)

validation_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'validation'),
    image_size=image_size,
    batch_size=batch_size)

test_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'test'),
    image_size=image_size,
    batch_size=batch_size)
# Out:
# Found 5494 files belonging to 6 classes.
# Found 1568 files belonging to 6 classes.
# Found 790 files belonging to 6 classes.
# 2024-11-22 15:08:59.831812: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 15:08:59.836234: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 15:08:59.836342: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 15:08:59.836995: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 15:08:59.837097: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 15:08:59.837188: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 15:08:59.896013: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 15:08:59.896127: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 15:08:59.896204: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 15:08:59.896270: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22207 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# ### 마지막 Dense layer의 노드 수 및 activation 변경

# %%
# 모델 레이어 구성
inputs = keras.Input(shape=(400, 400, 3))

x = layers.Rescaling(1./255)(inputs)

x = layers.Conv2D(filters=32, kernel_size=3)(inputs)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=256, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Dropout(0.25)(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Flatten()(x)
x = layers.Dense(256, activation = "relu")(x)
x = layers.Dropout(0.25)(x)

# outputs = layers.Dense(1, activation="sigmoid")(x)
outputs = layers.Dense(6, activation="softmax")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  batch_normalization (Batch  (None, 398, 398, 32)      128
#  Normalization)
#
#  re_lu (ReLU)                (None, 398, 398, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 199, 199, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 197, 197, 64)      256
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 197, 197, 64)      0
#
#  max_pooling2d_1 (MaxPoolin  (None, 98, 98, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 96, 96, 128)       512
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 96, 96, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 48, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 46, 46, 256)       295168
#
#  batch_normalization_3 (Bat  (None, 46, 46, 256)       1024
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 46, 46, 256)       0
#
#  dropout (Dropout)           (None, 46, 46, 256)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 23, 23, 256)       0
#  g2D)
#
#  flatten (Flatten)           (None, 135424)            0
#
#  dense (Dense)               (None, 256)               34668800
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 35060678 (133.75 MB)
# Trainable params: 35059718 (133.74 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________

# %% [markdown]
# ### 손실함수 변경

# %%
# 학습률 및 옵티마이저 설정
optimizer = optimizers.RMSprop(learning_rate=1e-4)

# 모델 컴파일
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',   # loss='binary_crossentropy'
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# EarlyStopping 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss',       # 검증 손실을 기준으로 학습 중단
    patience=5,               # 성능이 개선되지 않는 에포크 수 (5회 연속 개선 없을 시 중단)
    restore_best_weights=True # 최적의 가중치 복원
)

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,
    callbacks=[early_stopping],
    batch_size=batch_size)
# Out:
# Epoch 1/100
# 2024-11-22 15:09:00.958543: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-11-22 15:09:01.533645: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-11-22 15:09:01.957632: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-11-22 15:09:01.972566: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x70e6cb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-22 15:09:01.972586: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-11-22 15:09:01.975690: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-22 15:09:02.045948: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 172/172 [==============================] - 22s 108ms/step - loss: 2.5758 - accuracy: 0.6296 - val_loss: 1.0278 - val_accuracy: 0.5957
# Epoch 2/100
# 172/172 [==============================] - 18s 101ms/step - loss: 0.7127 - accuracy: 0.7685 - val_loss: 0.5126 - val_accuracy: 0.8233
# Epoch 3/100
# 172/172 [==============================] - 18s 102ms/step - loss: 0.5337 - accuracy: 0.8320 - val_loss: 0.3899 - val_accuracy: 0.8673
# Epoch 4/100
# 172/172 [==============================] - 18s 101ms/step - loss: 0.4704 - accuracy: 0.8466 - val_loss: 0.6996 - val_accuracy: 0.7895
# Epoch 5/100
# 172/172 [==============================] - 18s 101ms/step - loss: 0.4405 - accuracy: 0.8637 - val_loss: 0.3666 - val_accuracy: 0.8846
# Epoch 6/100
# 172/172 [==============================] - 18s 101ms/step - loss: 0.3638 - accuracy: 0.8875 - val_loss: 0.5172 - val_accuracy: 0.8380
# Epoch 7/100
# 172/172 [==============================] - 18s 101ms/step - loss: 0.3525 - accuracy: 0.8897 - val_loss: 0.4715 - val_accuracy: 0.8635
# Epoch 8/100
# 172/172 [==============================] - 18s 101ms/step - loss: 0.3016 - accuracy: 0.9037 - val_loss: 0.8032 - val_accuracy: 0.8393
# Epoch 9/100
# 172/172 [==============================] - 18s 101ms/step - loss: 0.2857 - accuracy: 0.9104 - val_loss: 0.4133 - val_accuracy: 0.8756
# Epoch 10/100
# 172/172 [==============================] - 18s 102ms/step - loss: 0.2578 - accuracy: 0.9179 - val_loss: 0.5771 - val_accuracy: 0.8622

# %%
# 훈련 정확도와 손실 그래프 생성
import matplotlib.pyplot as plt 

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# %% [markdown]
# # Analysis - Training & Validation
# 전체적으로 `Step1/6.Change_Conv2D_Dense` 모델과 비슷한 형태
#
# ## 과적합
# training과 validation 두 그래프가 서로 다른 경향성으로 진행
#
# ## 불안정
# validation 그래프가 약간 진동하며 불안정한 형태
#
# ---

# %%
test_loss, test_acc = model.evaluate(test_dataset)

print(f"test accuracy: {test_acc}")
print(f"test loss: {test_loss}")
# Out:
# 25/25 [==============================] - 1s 41ms/step - loss: 0.3537 - accuracy: 0.8848
# test accuracy: 0.8848101496696472
# test loss: 0.35372394323349

# %% [markdown]
# # Analysis - Test
# (compared to `Step1/6.Change_Conv2D_Dense`)
# Accuracy : 94.8% → 88.5%
# Loss : 0.1188 → 0.3537
# 클래스의 증가로 성능이 감소한 것으로 추측됨
