# %% [markdown]
# # Guide
# ## Data
# [[Google Drive] /Data/Final/Step2-1.zip](https://drive.google.com/file/d/1KjVfu9UgvK0_tZtuOcJmaRCn44CtYxUq/view?usp=sharing)
# ## Code
# In [3] `base_dir` : 실제 데이터 경로로 변경 필요
#
# ---

# %% [markdown]
# # Purpose
# - 새로운 데이터 학습 결과 확인
# - Step1에서 좋은 성능의 모델 적용
# [[Googld Drive] /Code/Step1/9-2.Data_Added_Adam.ipynb](구글 드라이브)
#
# ## Alternation
# (compared to) `9-2.Data_Added_Adam` 모델
# - Data: Data_Initial/Step2-1 → Data_Final/Step2-1
# - 2개의 클래스 분류 → 6개의 클래스 분류
# ⇒ 마지막 layer의 노드 수, activation, 손실 함수 변경

# %%
from tensorflow import keras
from tensorflow.keras import layers, optimizers
import os
# Out:
# 2024-11-22 20:25:23.727795: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
image_size = (400, 400)
batch_size = 32

# %% [markdown]
# ### Data 변경

# %%
# 데이터셋 로드
from tensorflow.keras.utils import image_dataset_from_directory

# 실제 데이터의 경로로 변경 필요
base_dir = "/tf/Fixed_Data/Data_Final/Step2-1"   # Data_Final/Step1

train_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'train'),
    image_size=image_size,
    batch_size=batch_size)

validation_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'validation'),
    image_size=image_size,
    batch_size=batch_size)

test_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'test'),
    image_size=image_size,
    batch_size=batch_size)
# Out:
# Found 3780 files belonging to 6 classes.
# Found 1080 files belonging to 6 classes.
# Found 540 files belonging to 6 classes.
# 2024-11-22 20:25:25.206667: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 20:25:25.210878: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 20:25:25.210992: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 20:25:25.211660: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 20:25:25.211800: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 20:25:25.211897: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 20:25:25.272513: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 20:25:25.272625: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 20:25:25.272702: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-22 20:25:25.272767: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22207 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# ### 마지막 Dense layer의 노드 수 및 activation 변경

# %%
# 모델 레이어 구성
inputs = keras.Input(shape=(400, 400, 3))

x = layers.Rescaling(1./255)(inputs)

x = layers.Conv2D(filters=32, kernel_size=3)(inputs)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=256, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=512, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Dropout(0.3)(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Flatten()(x)
x = layers.Dense(512, activation = "relu")(x)
x = layers.Dropout(0.3)(x)

# outputs = layers.Dense(1, activation="sigmoid")(x)
outputs = layers.Dense(6, activation="softmax")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  batch_normalization (Batch  (None, 398, 398, 32)      128
#  Normalization)
#
#  re_lu (ReLU)                (None, 398, 398, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 199, 199, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 197, 197, 64)      256
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 197, 197, 64)      0
#
#  max_pooling2d_1 (MaxPoolin  (None, 98, 98, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 96, 96, 128)       512
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 96, 96, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 48, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 46, 46, 256)       295168
#
#  batch_normalization_3 (Bat  (None, 46, 46, 256)       1024
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 46, 46, 256)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 23, 23, 256)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 21, 21, 512)       1180160
#
#  batch_normalization_4 (Bat  (None, 21, 21, 512)       2048
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 21, 21, 512)       0
#
#  dropout (Dropout)           (None, 21, 21, 512)       0
#
#  max_pooling2d_4 (MaxPoolin  (None, 10, 10, 512)       0
#  g2D)
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 512)               26214912
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 6)                 3078
#
# =================================================================
# Total params: 27790534 (106.01 MB)
# Trainable params: 27788550 (106.00 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %% [markdown]
# ### 손실함수 변경

# %%
# 학습률 및 옵티마이저 설정
optimizer = optimizers.Adam(learning_rate=1e-4)

# 모델 컴파일
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',   # loss='binary_crossentropy'
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# EarlyStopping 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss',       # 검증 손실을 기준으로 학습 중단
    patience=5,               # 성능이 개선되지 않는 에포크 수 (5회 연속 개선 없을 시 중단)
    restore_best_weights=True # 최적의 가중치 복원
)

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,
    callbacks=[early_stopping],
    batch_size=batch_size)
# Out:
# Epoch 1/100
# 2024-11-22 20:25:26.645970: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-11-22 20:25:27.320257: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-11-22 20:25:27.776904: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-11-22 20:25:27.794305: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x773f060 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-22 20:25:27.794326: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-11-22 20:25:27.797692: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-22 20:25:27.885922: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 119/119 [==============================] - 18s 109ms/step - loss: 1.5865 - accuracy: 0.6357 - val_loss: 1.3790 - val_accuracy: 0.4556
# Epoch 2/100
# 119/119 [==============================] - 13s 103ms/step - loss: 0.5769 - accuracy: 0.7839 - val_loss: 0.8428 - val_accuracy: 0.6639
# Epoch 3/100
# 119/119 [==============================] - 13s 103ms/step - loss: 0.4923 - accuracy: 0.8228 - val_loss: 0.4611 - val_accuracy: 0.8463
# Epoch 4/100
# 119/119 [==============================] - 13s 102ms/step - loss: 0.4301 - accuracy: 0.8463 - val_loss: 0.4796 - val_accuracy: 0.8343
# Epoch 5/100
# 119/119 [==============================] - 13s 103ms/step - loss: 0.3757 - accuracy: 0.8667 - val_loss: 0.4069 - val_accuracy: 0.8593
# Epoch 6/100
# 119/119 [==============================] - 13s 102ms/step - loss: 0.3527 - accuracy: 0.8733 - val_loss: 0.4101 - val_accuracy: 0.8537
# Epoch 7/100
# 119/119 [==============================] - 13s 103ms/step - loss: 0.2972 - accuracy: 0.8958 - val_loss: 0.3577 - val_accuracy: 0.8759
# Epoch 8/100
# 119/119 [==============================] - 13s 103ms/step - loss: 0.3024 - accuracy: 0.8958 - val_loss: 0.3092 - val_accuracy: 0.8991
# Epoch 9/100
# 119/119 [==============================] - 13s 102ms/step - loss: 0.2591 - accuracy: 0.9111 - val_loss: 0.3373 - val_accuracy: 0.8713
# Epoch 10/100
# 119/119 [==============================] - 13s 102ms/step - loss: 0.2409 - accuracy: 0.9135 - val_loss: 0.3865 - val_accuracy: 0.8639
# Epoch 11/100
# 119/119 [==============================] - 13s 102ms/step - loss: 0.1934 - accuracy: 0.9307 - val_loss: 0.5925 - val_accuracy: 0.8157
# Epoch 12/100
# 119/119 [==============================] - 13s 102ms/step - loss: 0.1757 - accuracy: 0.9397 - val_loss: 0.3547 - val_accuracy: 0.8815
# Epoch 13/100
# 119/119 [==============================] - 13s 102ms/step - loss: 0.1791 - accuracy: 0.9328 - val_loss: 0.2991 - val_accuracy: 0.8954
# Epoch 14/100
# 119/119 [==============================] - 13s 102ms/step - loss: 0.1561 - accuracy: 0.9476 - val_loss: 0.3324 - val_accuracy: 0.8750
# Epoch 15/100
# 119/119 [==============================] - 13s 102ms/step - loss: 0.2169 - accuracy: 0.9212 - val_loss: 0.3974 - val_accuracy: 0.8583
# Epoch 16/100
# 119/119 [==============================] - 13s 102ms/step - loss: 0.1456 - accuracy: 0.9479 - val_loss: 0.3368 - val_accuracy: 0.8806
# Epoch 17/100
# 119/119 [==============================] - 13s 102ms/step - loss: 0.1214 - accuracy: 0.9561 - val_loss: 0.5391 - val_accuracy: 0.8500
# Epoch 18/100
# 119/119 [==============================] - 13s 102ms/step - loss: 0.1765 - accuracy: 0.9410 - val_loss: 0.3363 - val_accuracy: 0.8963

# %%
# 훈련 정확도와 손실 그래프 생성
import matplotlib.pyplot as plt 

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# %% [markdown]
# # Analysis - Training & Validation
# ## 불안정
# validation 그래프가 약간 진동하며 불안정한 형태
#
# ---

# %%
test_loss, test_acc = model.evaluate(test_dataset)

print(f"test accuracy: {test_acc}")
print(f"test loss: {test_loss}")
# Out:
# 17/17 [==============================] - 1s 54ms/step - loss: 0.3037 - accuracy: 0.9000
# test accuracy: 0.8999999761581421
# test loss: 0.3036690950393677

# %% [markdown]
# # Analysis - Test
# (compared to) `Step1/9-2.Data_Added_Adam` 모델
# Accuracy : 92.1% → 90.0%
# Loss : 0.1808 → 0.3037
# 클래스의 증가로 성능이 감소한 것으로 추측됨
