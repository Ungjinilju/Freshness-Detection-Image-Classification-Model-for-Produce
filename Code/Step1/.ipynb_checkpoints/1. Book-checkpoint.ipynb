# %% [markdown]
# # Guide
# ## Data
# [[Google Drive] /Data/Initial/Step1.zip](https://drive.google.com/file/d/1LpnhjeBOoLH-QwbVOovCk-OpdpmIQAaZ/view?usp=sharing?usp=sharing)
# ## Code
# In [3] `base_dir` : 실제 데이터 경로로 변경 필요
#
# ---

# %% [markdown]
# # 교재 Chaper 8-2 Code
# 적은 데이터를 사용한 이진 이미지 분류 모델
# 데이터 로드, 모델의 layer 구성 및 파라미터, 결과 시각화 코드 참고

# %%
from tensorflow import keras
from tensorflow.keras import layers
import os
# Out:
# 2024-11-20 12:45:47.490602: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
image_size = (400, 400)
batch_size = 32

# %% [markdown]
# ### Source : 교재 코드 8-9

# %%
# 데이터셋 로드
from tensorflow.keras.utils import image_dataset_from_directory

# 실제 데이터의 경로로 변경 필요
base_dir = "/tf/Fixed_Data/Data_Initial/Step1"

train_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'train'),
    image_size=image_size,
    batch_size=batch_size)

validation_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'validation'),
    image_size=image_size,
    batch_size=batch_size)

test_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'test'),
    image_size=image_size,
    batch_size=batch_size)
# Out:
# Found 1731 files belonging to 2 classes.
# Found 494 files belonging to 2 classes.
# Found 249 files belonging to 2 classes.
# 2024-11-20 12:45:48.910188: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 12:45:48.913401: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 12:45:48.913495: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 12:45:48.914134: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 12:45:48.914214: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 12:45:48.914284: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 12:45:48.955633: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 12:45:48.955784: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 12:45:48.955862: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 12:45:48.955929: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21583 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# ### Source : 교재 코드 8-7

# %%
# 모델 레이어 구성
inputs = keras.Input(shape=(400, 400, 3))

x = layers.Rescaling(1./255)(inputs)

x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)

x = layers.Flatten()(x)

outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 199, 199, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 98, 98, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 48, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 46, 46, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 23, 23, 256)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 21, 21, 256)       590080
#
#  flatten (Flatten)           (None, 112896)            0
#
#  dense (Dense)               (None, 1)                 112897
#
# =================================================================
# Total params: 1091393 (4.16 MB)
# Trainable params: 1091393 (4.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Source : 교재 코드 8-8

# %%
model.compile(optimizer='rmsprop',
              loss="binary_crossentropy",
              metrics=['accuracy'])

# %% [markdown]
# ### Source : 교재 코드 8-11

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=30)
# Out:
# Epoch 1/30
# 2024-11-20 12:45:50.406810: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-11-20 12:45:50.637838: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-11-20 12:45:50.638173: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f7bdc751b60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-20 12:45:50.638188: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-11-20 12:45:50.641267: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-20 12:45:50.715881: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 55/55 [==============================] - 7s 73ms/step - loss: 0.8720 - accuracy: 0.5708 - val_loss: 0.8446 - val_accuracy: 0.4656
# Epoch 2/30
# 55/55 [==============================] - 4s 64ms/step - loss: 0.6376 - accuracy: 0.6898 - val_loss: 0.4792 - val_accuracy: 0.7794
# Epoch 3/30
# 55/55 [==============================] - 4s 63ms/step - loss: 0.4905 - accuracy: 0.7891 - val_loss: 0.4479 - val_accuracy: 0.8300
# Epoch 4/30
# 55/55 [==============================] - 4s 66ms/step - loss: 0.4321 - accuracy: 0.8047 - val_loss: 0.4332 - val_accuracy: 0.8401
# Epoch 5/30
# 55/55 [==============================] - 4s 64ms/step - loss: 0.3912 - accuracy: 0.8481 - val_loss: 0.3249 - val_accuracy: 0.8644
# Epoch 6/30
# 55/55 [==============================] - 4s 64ms/step - loss: 0.3688 - accuracy: 0.8602 - val_loss: 0.9935 - val_accuracy: 0.7895
# Epoch 7/30
# 55/55 [==============================] - 4s 64ms/step - loss: 0.3798 - accuracy: 0.8382 - val_loss: 0.4748 - val_accuracy: 0.7874
# Epoch 8/30
# 55/55 [==============================] - 4s 64ms/step - loss: 0.3334 - accuracy: 0.8631 - val_loss: 0.3238 - val_accuracy: 0.8664
# Epoch 9/30
# 55/55 [==============================] - 4s 63ms/step - loss: 0.2773 - accuracy: 0.8949 - val_loss: 0.5019 - val_accuracy: 0.8644
# Epoch 10/30
# 55/55 [==============================] - 4s 63ms/step - loss: 0.2676 - accuracy: 0.8983 - val_loss: 0.3985 - val_accuracy: 0.8623
# Epoch 11/30
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2640 - accuracy: 0.8972 - val_loss: 0.3714 - val_accuracy: 0.8704
# Epoch 12/30
# 55/55 [==============================] - 4s 63ms/step - loss: 0.2144 - accuracy: 0.9133 - val_loss: 0.4936 - val_accuracy: 0.8522
# Epoch 13/30
# 55/55 [==============================] - 4s 63ms/step - loss: 0.1872 - accuracy: 0.9232 - val_loss: 1.4170 - val_accuracy: 0.7409
# Epoch 14/30
# 55/55 [==============================] - 4s 65ms/step - loss: 0.1550 - accuracy: 0.9434 - val_loss: 0.5875 - val_accuracy: 0.8198
# Epoch 15/30
# 55/55 [==============================] - 4s 64ms/step - loss: 0.1819 - accuracy: 0.9417 - val_loss: 0.4248 - val_accuracy: 0.8968
# Epoch 16/30
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2019 - accuracy: 0.9336 - val_loss: 0.4361 - val_accuracy: 0.8725
# Epoch 17/30
# 55/55 [==============================] - 4s 64ms/step - loss: 0.1140 - accuracy: 0.9521 - val_loss: 1.0564 - val_accuracy: 0.7955
# Epoch 18/30
# 55/55 [==============================] - 4s 62ms/step - loss: 0.1532 - accuracy: 0.9509 - val_loss: 0.3882 - val_accuracy: 0.9008
# Epoch 19/30
# 55/55 [==============================] - 4s 64ms/step - loss: 0.1869 - accuracy: 0.9590 - val_loss: 0.6573 - val_accuracy: 0.8725
# Epoch 20/30
# 55/55 [==============================] - 4s 62ms/step - loss: 0.1030 - accuracy: 0.9665 - val_loss: 0.6013 - val_accuracy: 0.8704
# Epoch 21/30
# 55/55 [==============================] - 4s 63ms/step - loss: 0.1778 - accuracy: 0.9601 - val_loss: 0.5361 - val_accuracy: 0.8502
# Epoch 22/30
# 55/55 [==============================] - 4s 63ms/step - loss: 0.0834 - accuracy: 0.9804 - val_loss: 1.8087 - val_accuracy: 0.7591
# Epoch 23/30
# 55/55 [==============================] - 4s 63ms/step - loss: 0.0849 - accuracy: 0.9752 - val_loss: 0.6914 - val_accuracy: 0.8947
# Epoch 24/30
# 55/55 [==============================] - 4s 64ms/step - loss: 0.0940 - accuracy: 0.9775 - val_loss: 0.9857 - val_accuracy: 0.8806
# Epoch 25/30
# 55/55 [==============================] - 4s 64ms/step - loss: 0.1050 - accuracy: 0.9740 - val_loss: 0.7562 - val_accuracy: 0.8927
# Epoch 26/30
# 55/55 [==============================] - 4s 62ms/step - loss: 0.0526 - accuracy: 0.9821 - val_loss: 0.8352 - val_accuracy: 0.8846
# Epoch 27/30
# 55/55 [==============================] - 4s 63ms/step - loss: 0.0898 - accuracy: 0.9769 - val_loss: 0.8756 - val_accuracy: 0.8947
# Epoch 28/30
# 55/55 [==============================] - 4s 64ms/step - loss: 0.0760 - accuracy: 0.9780 - val_loss: 1.0825 - val_accuracy: 0.8401
# Epoch 29/30
# 55/55 [==============================] - 4s 65ms/step - loss: 0.0791 - accuracy: 0.9786 - val_loss: 1.7429 - val_accuracy: 0.7955
# Epoch 30/30
# 55/55 [==============================] - 4s 65ms/step - loss: 0.0550 - accuracy: 0.9844 - val_loss: 1.0160 - val_accuracy: 0.8765

# %% [markdown]
# ### Source : 교재 코드 8-12

# %%
# 훈련 정확도와 손실 그래프 생성
import matplotlib.pyplot as plt 

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# %% [markdown]
# # Analysis - Training & Validation
# ## 과적합
# 훈련이 진행될 수록 Training과 Validation의 Accuracy, Loss의 차이가 증가
#
# ## 불안정
# 전체적으로 그래프가 크게 진동하는 형태. 특히 Validation Accuracy와 Loss가 특정 Epoch에서 급격히 증가/감소
# 훈련이 진행되어도 원만한 형태로 수렴하지 않음
#
# ---

# %%
test_loss, test_acc = model.evaluate(test_dataset)

print(f"test accuracy: {test_acc}")
print(f"test loss: {test_loss}")
# Out:
# 8/8 [==============================] - 1s 36ms/step - loss: 1.2064 - accuracy: 0.8313
# test accuracy: 0.8313252925872803
# test loss: 1.2063660621643066

# %% [markdown]
# # Analysis - Test
# 이진 분류임에도 83% 정도의 낮은 Accuracy
