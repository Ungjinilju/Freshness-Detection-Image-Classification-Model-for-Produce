# %% [markdown]
# # Guide
# ## Data
# [[Google Drive] /Data/Initial/Step1.zip](https://drive.google.com/file/d/1LpnhjeBOoLH-QwbVOovCk-OpdpmIQAaZ/view?usp=sharing?usp=sharing)
# ## Code
# In [3] `base_dir` : 실제 데이터 경로로 변경 필요
#
# ---

# %% [markdown]
# # Purpose
# Validation Accuracy, Loss 그래프의 진동 폭 감소
#
# ## Alternation
# (compared to) `6. Change_Conv2D_Dense` 모델
# learning_rate = 1e-4 → learning_rate = 1e-5

# %%
from tensorflow import keras
from tensorflow.keras import layers, optimizers
import os
# Out:
# 2024-11-21 06:22:15.441163: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
image_size = (400, 400)
batch_size = 32

# %%
# 데이터셋 로드
from tensorflow.keras.utils import image_dataset_from_directory

# 실제 데이터의 경로로 변경 필요
base_dir = "/tf/Fixed_Data/Data_Initial/Step1"

train_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'train'),
    image_size=image_size,
    batch_size=batch_size)

validation_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'validation'),
    image_size=image_size,
    batch_size=batch_size)

test_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'test'),
    image_size=image_size,
    batch_size=batch_size)
# Out:
# Found 1732 files belonging to 2 classes.
# Found 494 files belonging to 2 classes.
# Found 249 files belonging to 2 classes.
# 2024-11-21 06:22:16.825176: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:22:16.828525: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:22:16.828612: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:22:16.829243: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:22:16.829324: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:22:16.829395: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:22:16.881323: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:22:16.881443: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:22:16.881524: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:22:16.881591: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22209 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# 모델 레이어 구성
inputs = keras.Input(shape=(400, 400, 3))

x = layers.Rescaling(1./255)(inputs)

x = layers.Conv2D(filters=32, kernel_size=3)(inputs)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=256, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Dropout(0.25)(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Flatten()(x)
x = layers.Dense(256, activation = "relu")(x) 
x = layers.Dropout(0.25)(x)

outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  batch_normalization (Batch  (None, 398, 398, 32)      128
#  Normalization)
#
#  re_lu (ReLU)                (None, 398, 398, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 199, 199, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 197, 197, 64)      256
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 197, 197, 64)      0
#
#  max_pooling2d_1 (MaxPoolin  (None, 98, 98, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 96, 96, 128)       512
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 96, 96, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 48, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 46, 46, 256)       295168
#
#  batch_normalization_3 (Bat  (None, 46, 46, 256)       1024
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 46, 46, 256)       0
#
#  dropout (Dropout)           (None, 46, 46, 256)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 23, 23, 256)       0
#  g2D)
#
#  flatten (Flatten)           (None, 135424)            0
#
#  dense (Dense)               (None, 256)               34668800
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 35059393 (133.74 MB)
# Trainable params: 35058433 (133.74 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________

# %% [markdown]
# ### learning_rate 변경

# %%
# 학습률 설정
optimizer = optimizers.RMSprop(learning_rate=1e-5)

# 모델 컴파일
model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# EarlyStopping 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss',       # 검증 손실을 기준으로 학습 중단
    patience=5,               # 성능이 개선되지 않는 에포크 수 (5회 연속 개선 없을 시 중단)
    restore_best_weights=True # 최적의 가중치 복원
)

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,
    callbacks=[early_stopping],
    batch_size=batch_size)
# Out:
# Epoch 1/100
# 2024-11-21 06:22:17.975135: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-11-21 06:22:18.587279: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-11-21 06:22:19.036392: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-11-21 06:22:19.050907: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fe3967dbfe0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-21 06:22:19.050928: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-11-21 06:22:19.053886: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-21 06:22:19.122624: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 55/55 [==============================] - 10s 112ms/step - loss: 0.7685 - accuracy: 0.7315 - val_loss: 0.7481 - val_accuracy: 0.4555
# Epoch 2/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.2948 - accuracy: 0.8666 - val_loss: 0.7443 - val_accuracy: 0.4879
# Epoch 3/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2153 - accuracy: 0.9013 - val_loss: 0.7029 - val_accuracy: 0.6275
# Epoch 4/100
# 55/55 [==============================] - 6s 107ms/step - loss: 0.2133 - accuracy: 0.9180 - val_loss: 0.3040 - val_accuracy: 0.8785
# Epoch 5/100
# 55/55 [==============================] - 6s 103ms/step - loss: 0.1345 - accuracy: 0.9423 - val_loss: 0.4729 - val_accuracy: 0.7449
# Epoch 6/100
# 55/55 [==============================] - 6s 108ms/step - loss: 0.1009 - accuracy: 0.9579 - val_loss: 0.2222 - val_accuracy: 0.9109
# Epoch 7/100
# 55/55 [==============================] - 6s 107ms/step - loss: 0.0882 - accuracy: 0.9619 - val_loss: 0.5747 - val_accuracy: 0.7490
# Epoch 8/100
# 55/55 [==============================] - 6s 107ms/step - loss: 0.0705 - accuracy: 0.9729 - val_loss: 0.3370 - val_accuracy: 0.8765
# Epoch 9/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.0484 - accuracy: 0.9827 - val_loss: 0.1959 - val_accuracy: 0.9231
# Epoch 10/100
# 55/55 [==============================] - 6s 105ms/step - loss: 0.0409 - accuracy: 0.9850 - val_loss: 2.2475 - val_accuracy: 0.5202
# Epoch 11/100
# 55/55 [==============================] - 6s 104ms/step - loss: 0.0608 - accuracy: 0.9809 - val_loss: 0.2054 - val_accuracy: 0.9150
# Epoch 12/100
# 55/55 [==============================] - 6s 109ms/step - loss: 0.0225 - accuracy: 0.9942 - val_loss: 0.1573 - val_accuracy: 0.9494
# Epoch 13/100
# 55/55 [==============================] - 6s 109ms/step - loss: 0.0319 - accuracy: 0.9890 - val_loss: 0.1439 - val_accuracy: 0.9494
# Epoch 14/100
# 55/55 [==============================] - 6s 105ms/step - loss: 0.0282 - accuracy: 0.9896 - val_loss: 0.1474 - val_accuracy: 0.9453
# Epoch 15/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.0253 - accuracy: 0.9925 - val_loss: 0.1962 - val_accuracy: 0.9372
# Epoch 16/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.0151 - accuracy: 0.9960 - val_loss: 0.1947 - val_accuracy: 0.9291
# Epoch 17/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.3263 - val_accuracy: 0.9069
# Epoch 18/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.0244 - accuracy: 0.9919 - val_loss: 0.1351 - val_accuracy: 0.9575
# Epoch 19/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0109 - accuracy: 0.9977 - val_loss: 0.4774 - val_accuracy: 0.8320
# Epoch 20/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0101 - accuracy: 0.9960 - val_loss: 0.3021 - val_accuracy: 0.8947
# Epoch 21/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.0137 - accuracy: 0.9948 - val_loss: 0.5851 - val_accuracy: 0.8158
# Epoch 22/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.0128 - accuracy: 0.9954 - val_loss: 0.1340 - val_accuracy: 0.9575
# Epoch 23/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.0138 - accuracy: 0.9936 - val_loss: 0.1302 - val_accuracy: 0.9514
# Epoch 24/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 0.1616 - val_accuracy: 0.9474
# Epoch 25/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.0039 - accuracy: 0.9983 - val_loss: 0.1614 - val_accuracy: 0.9433
# Epoch 26/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.1714 - val_accuracy: 0.9413
# Epoch 27/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.1429 - val_accuracy: 0.9575
# Epoch 28/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.1536 - val_accuracy: 0.9575

# %%
# 훈련 정확도와 손실 그래프 생성
import matplotlib.pyplot as plt 

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# %% [markdown]
# # Analysis - Training & Validation
# ## 불안정
# 큰 향상이 보이지 않음
# 일부 Epoch에서는 진동폭이 더 증가
#
# ---

# %%
test_loss, test_acc = model.evaluate(test_dataset)

print(f"test accuracy: {test_acc}")
print(f"test loss: {test_loss}")
# Out:
# 8/8 [==============================] - 1s 56ms/step - loss: 0.1269 - accuracy: 0.9478
# test accuracy: 0.9477911591529846
# test loss: 0.12693382799625397

# %% [markdown]
# # Analysis - Test
# (compared to `6. Change_Conv2D_Dense`)
# Accuracy : 96.4% → 94.8%
# Loss : 0.1188 → 0.1269
# 성능이 약간 감소하였으나 비슷한 수준
