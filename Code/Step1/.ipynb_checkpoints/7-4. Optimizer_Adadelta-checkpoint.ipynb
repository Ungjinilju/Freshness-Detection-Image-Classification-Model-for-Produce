# %% [markdown]
# # Guide
# ## Data
# [[Google Drive] /Data/Initial/Step1.zip](https://drive.google.com/file/d/1LpnhjeBOoLH-QwbVOovCk-OpdpmIQAaZ/view?usp=sharing?usp=sharing)
# ## Code
# In [3] `base_dir` : 실제 데이터 경로로 변경 필요
#
# ---

# %% [markdown]
# # Purpose
# Validation Accuracy, Loss 그래프의 진동 폭 감소
#
# ## Alternation
# (compared to) `6. Change_Conv2D_Dense` 모델
# Optimizer : RMSprop → Adadelta

# %%
from tensorflow import keras
from tensorflow.keras import layers, optimizers
import os
# Out:
# 2024-11-21 06:31:48.739898: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
image_size = (400, 400)
batch_size = 32

# %%
# 데이터셋 로드
from tensorflow.keras.utils import image_dataset_from_directory

# 실제 데이터의 경로로 변경 필요
base_dir = "/tf/Fixed_Data/Data_Initial/Step1"

train_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'train'),
    image_size=image_size,
    batch_size=batch_size)

validation_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'validation'),
    image_size=image_size,
    batch_size=batch_size)

test_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'test'),
    image_size=image_size,
    batch_size=batch_size)
# Out:
# Found 1732 files belonging to 2 classes.
# Found 494 files belonging to 2 classes.
# Found 249 files belonging to 2 classes.
# 2024-11-21 06:31:50.148154: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:31:50.151376: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:31:50.151465: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:31:50.152247: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:31:50.152343: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:31:50.152415: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:31:50.210687: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:31:50.210800: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:31:50.210880: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 06:31:50.210947: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22209 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# 모델 레이어 구성
inputs = keras.Input(shape=(400, 400, 3))

x = layers.Rescaling(1./255)(inputs)

x = layers.Conv2D(filters=32, kernel_size=3)(inputs)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=256, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Dropout(0.25)(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Flatten()(x)
x = layers.Dense(256, activation = "relu")(x)
x = layers.Dropout(0.25)(x)

outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  batch_normalization (Batch  (None, 398, 398, 32)      128
#  Normalization)
#
#  re_lu (ReLU)                (None, 398, 398, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 199, 199, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 197, 197, 64)      256
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 197, 197, 64)      0
#
#  max_pooling2d_1 (MaxPoolin  (None, 98, 98, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 96, 96, 128)       512
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 96, 96, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 48, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 46, 46, 256)       295168
#
#  batch_normalization_3 (Bat  (None, 46, 46, 256)       1024
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 46, 46, 256)       0
#
#  dropout (Dropout)           (None, 46, 46, 256)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 23, 23, 256)       0
#  g2D)
#
#  flatten (Flatten)           (None, 135424)            0
#
#  dense (Dense)               (None, 256)               34668800
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 35059393 (133.74 MB)
# Trainable params: 35058433 (133.74 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________

# %% [markdown]
# ### Optimizer 변경

# %%
# 학습률 설정
# optimizer = optimizers.RMSprop(learning_rate=1e-4)
# 옵티마이저 변경
optimizer = optimizers.Adadelta(learning_rate=1e-4)

# 모델 컴파일
model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# EarlyStopping 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss',       # 검증 손실을 기준으로 학습 중단
    patience=5,               # 성능이 개선되지 않는 에포크 수 (5회 연속 개선 없을 시 중단)
    restore_best_weights=True # 최적의 가중치 복원
)

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,
    callbacks=[early_stopping],
    batch_size=batch_size)
# Out:
# Epoch 1/100
# 2024-11-21 06:31:51.471526: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-11-21 06:31:52.036000: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-11-21 06:31:52.467032: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-11-21 06:31:52.482549: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7ff380dffc90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-21 06:31:52.482570: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-11-21 06:31:52.485732: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-21 06:31:52.560949: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 55/55 [==============================] - 10s 114ms/step - loss: 0.7130 - accuracy: 0.6120 - val_loss: 0.7118 - val_accuracy: 0.4899
# Epoch 2/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.5984 - accuracy: 0.6894 - val_loss: 0.6933 - val_accuracy: 0.5243
# Epoch 3/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.5634 - accuracy: 0.7182 - val_loss: 0.6231 - val_accuracy: 0.6457
# Epoch 4/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.5089 - accuracy: 0.7540 - val_loss: 0.5423 - val_accuracy: 0.7692
# Epoch 5/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.4961 - accuracy: 0.7742 - val_loss: 0.4781 - val_accuracy: 0.8178
# Epoch 6/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.4633 - accuracy: 0.7731 - val_loss: 0.4331 - val_accuracy: 0.8360
# Epoch 7/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.4499 - accuracy: 0.7846 - val_loss: 0.4004 - val_accuracy: 0.8543
# Epoch 8/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.4184 - accuracy: 0.8072 - val_loss: 0.3804 - val_accuracy: 0.8623
# Epoch 9/100
# 55/55 [==============================] - 6s 103ms/step - loss: 0.4143 - accuracy: 0.8181 - val_loss: 0.3650 - val_accuracy: 0.8745
# Epoch 10/100
# 55/55 [==============================] - 6s 103ms/step - loss: 0.4156 - accuracy: 0.8095 - val_loss: 0.3529 - val_accuracy: 0.8745
# Epoch 11/100
# 55/55 [==============================] - 6s 103ms/step - loss: 0.3992 - accuracy: 0.8262 - val_loss: 0.3466 - val_accuracy: 0.8664
# Epoch 12/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.3775 - accuracy: 0.8326 - val_loss: 0.3363 - val_accuracy: 0.8806
# Epoch 13/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.3621 - accuracy: 0.8453 - val_loss: 0.3301 - val_accuracy: 0.8785
# Epoch 14/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.3623 - accuracy: 0.8424 - val_loss: 0.3281 - val_accuracy: 0.8765
# Epoch 15/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.3700 - accuracy: 0.8303 - val_loss: 0.3175 - val_accuracy: 0.8866
# Epoch 16/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.3465 - accuracy: 0.8510 - val_loss: 0.3159 - val_accuracy: 0.8806
# Epoch 17/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.3431 - accuracy: 0.8533 - val_loss: 0.3102 - val_accuracy: 0.8887
# Epoch 18/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.3299 - accuracy: 0.8637 - val_loss: 0.3082 - val_accuracy: 0.8826
# Epoch 19/100
# 55/55 [==============================] - 6s 103ms/step - loss: 0.3283 - accuracy: 0.8551 - val_loss: 0.3025 - val_accuracy: 0.8866
# Epoch 20/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.3289 - accuracy: 0.8672 - val_loss: 0.2991 - val_accuracy: 0.8887
# Epoch 21/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.3127 - accuracy: 0.8689 - val_loss: 0.2962 - val_accuracy: 0.8907
# Epoch 22/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.3183 - accuracy: 0.8695 - val_loss: 0.2976 - val_accuracy: 0.8988
# Epoch 23/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.3135 - accuracy: 0.8649 - val_loss: 0.2952 - val_accuracy: 0.8988
# Epoch 24/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2914 - accuracy: 0.8764 - val_loss: 0.2900 - val_accuracy: 0.8968
# Epoch 25/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.2906 - accuracy: 0.8788 - val_loss: 0.2872 - val_accuracy: 0.8988
# Epoch 26/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.2889 - accuracy: 0.8811 - val_loss: 0.2840 - val_accuracy: 0.8988
# Epoch 27/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2777 - accuracy: 0.8811 - val_loss: 0.2839 - val_accuracy: 0.9049
# Epoch 28/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.2909 - accuracy: 0.8759 - val_loss: 0.2843 - val_accuracy: 0.9008
# Epoch 29/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2758 - accuracy: 0.8839 - val_loss: 0.2801 - val_accuracy: 0.9028
# Epoch 30/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2742 - accuracy: 0.8799 - val_loss: 0.2769 - val_accuracy: 0.9069
# Epoch 31/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2788 - accuracy: 0.8880 - val_loss: 0.2762 - val_accuracy: 0.9069
# Epoch 32/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2756 - accuracy: 0.8851 - val_loss: 0.2739 - val_accuracy: 0.9069
# Epoch 33/100
# 55/55 [==============================] - 6s 103ms/step - loss: 0.2679 - accuracy: 0.8839 - val_loss: 0.2736 - val_accuracy: 0.9069
# Epoch 34/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2595 - accuracy: 0.8880 - val_loss: 0.2715 - val_accuracy: 0.9089
# Epoch 35/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2649 - accuracy: 0.8909 - val_loss: 0.2684 - val_accuracy: 0.9089
# Epoch 36/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2612 - accuracy: 0.8839 - val_loss: 0.2678 - val_accuracy: 0.9069
# Epoch 37/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2633 - accuracy: 0.8955 - val_loss: 0.2652 - val_accuracy: 0.9150
# Epoch 38/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.2547 - accuracy: 0.8926 - val_loss: 0.2656 - val_accuracy: 0.9130
# Epoch 39/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.2500 - accuracy: 0.8961 - val_loss: 0.2634 - val_accuracy: 0.9150
# Epoch 40/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2462 - accuracy: 0.9001 - val_loss: 0.2620 - val_accuracy: 0.9170
# Epoch 41/100
# 55/55 [==============================] - 6s 103ms/step - loss: 0.2464 - accuracy: 0.8915 - val_loss: 0.2602 - val_accuracy: 0.9130
# Epoch 42/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2482 - accuracy: 0.8903 - val_loss: 0.2585 - val_accuracy: 0.9130
# Epoch 43/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2340 - accuracy: 0.9059 - val_loss: 0.2582 - val_accuracy: 0.9170
# Epoch 44/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.2421 - accuracy: 0.9024 - val_loss: 0.2590 - val_accuracy: 0.9170
# Epoch 45/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.2293 - accuracy: 0.9105 - val_loss: 0.2572 - val_accuracy: 0.9150
# Epoch 46/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2353 - accuracy: 0.9094 - val_loss: 0.2560 - val_accuracy: 0.9170
# Epoch 47/100
# 55/55 [==============================] - 6s 103ms/step - loss: 0.2381 - accuracy: 0.9001 - val_loss: 0.2549 - val_accuracy: 0.9170
# Epoch 48/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2296 - accuracy: 0.9082 - val_loss: 0.2547 - val_accuracy: 0.9190
# Epoch 49/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.2230 - accuracy: 0.9082 - val_loss: 0.2515 - val_accuracy: 0.9190
# Epoch 50/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2295 - accuracy: 0.9070 - val_loss: 0.2508 - val_accuracy: 0.9211
# Epoch 51/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.2099 - accuracy: 0.9140 - val_loss: 0.2492 - val_accuracy: 0.9211
# Epoch 52/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2101 - accuracy: 0.9203 - val_loss: 0.2482 - val_accuracy: 0.9211
# Epoch 53/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.2218 - accuracy: 0.9134 - val_loss: 0.2463 - val_accuracy: 0.9170
# Epoch 54/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.2281 - accuracy: 0.9105 - val_loss: 0.2474 - val_accuracy: 0.9211
# Epoch 55/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.2241 - accuracy: 0.9082 - val_loss: 0.2473 - val_accuracy: 0.9231
# Epoch 56/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2142 - accuracy: 0.9157 - val_loss: 0.2461 - val_accuracy: 0.9231
# Epoch 57/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2088 - accuracy: 0.9221 - val_loss: 0.2436 - val_accuracy: 0.9190
# Epoch 58/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2095 - accuracy: 0.9174 - val_loss: 0.2422 - val_accuracy: 0.9190
# Epoch 59/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1991 - accuracy: 0.9197 - val_loss: 0.2424 - val_accuracy: 0.9190
# Epoch 60/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.2062 - accuracy: 0.9186 - val_loss: 0.2415 - val_accuracy: 0.9211
# Epoch 61/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1941 - accuracy: 0.9255 - val_loss: 0.2395 - val_accuracy: 0.9190
# Epoch 62/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.1985 - accuracy: 0.9273 - val_loss: 0.2382 - val_accuracy: 0.9170
# Epoch 63/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1927 - accuracy: 0.9255 - val_loss: 0.2401 - val_accuracy: 0.9231
# Epoch 64/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1922 - accuracy: 0.9290 - val_loss: 0.2384 - val_accuracy: 0.9251
# Epoch 65/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1958 - accuracy: 0.9186 - val_loss: 0.2376 - val_accuracy: 0.9251
# Epoch 66/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1913 - accuracy: 0.9290 - val_loss: 0.2351 - val_accuracy: 0.9150
# Epoch 67/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1980 - accuracy: 0.9232 - val_loss: 0.2344 - val_accuracy: 0.9170
# Epoch 68/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.1910 - accuracy: 0.9249 - val_loss: 0.2339 - val_accuracy: 0.9211
# Epoch 69/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1832 - accuracy: 0.9324 - val_loss: 0.2335 - val_accuracy: 0.9211
# Epoch 70/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.1857 - accuracy: 0.9324 - val_loss: 0.2321 - val_accuracy: 0.9211
# Epoch 71/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1913 - accuracy: 0.9261 - val_loss: 0.2329 - val_accuracy: 0.9211
# Epoch 72/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1857 - accuracy: 0.9278 - val_loss: 0.2330 - val_accuracy: 0.9211
# Epoch 73/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.1790 - accuracy: 0.9400 - val_loss: 0.2302 - val_accuracy: 0.9170
# Epoch 74/100
# 55/55 [==============================] - 6s 103ms/step - loss: 0.1728 - accuracy: 0.9353 - val_loss: 0.2296 - val_accuracy: 0.9170
# Epoch 75/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1729 - accuracy: 0.9382 - val_loss: 0.2288 - val_accuracy: 0.9170
# Epoch 76/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1740 - accuracy: 0.9359 - val_loss: 0.2289 - val_accuracy: 0.9170
# Epoch 77/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.1892 - accuracy: 0.9197 - val_loss: 0.2279 - val_accuracy: 0.9170
# Epoch 78/100
# 55/55 [==============================] - 6s 103ms/step - loss: 0.1733 - accuracy: 0.9348 - val_loss: 0.2277 - val_accuracy: 0.9190
# Epoch 79/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.1676 - accuracy: 0.9405 - val_loss: 0.2274 - val_accuracy: 0.9190
# Epoch 80/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1688 - accuracy: 0.9324 - val_loss: 0.2258 - val_accuracy: 0.9170
# Epoch 81/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.1772 - accuracy: 0.9342 - val_loss: 0.2266 - val_accuracy: 0.9211
# Epoch 82/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.1597 - accuracy: 0.9382 - val_loss: 0.2260 - val_accuracy: 0.9190
# Epoch 83/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1680 - accuracy: 0.9348 - val_loss: 0.2230 - val_accuracy: 0.9190
# Epoch 84/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1651 - accuracy: 0.9376 - val_loss: 0.2253 - val_accuracy: 0.9211
# Epoch 85/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1749 - accuracy: 0.9417 - val_loss: 0.2235 - val_accuracy: 0.9170
# Epoch 86/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1669 - accuracy: 0.9353 - val_loss: 0.2220 - val_accuracy: 0.9211
# Epoch 87/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1613 - accuracy: 0.9452 - val_loss: 0.2216 - val_accuracy: 0.9211
# Epoch 88/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1627 - accuracy: 0.9423 - val_loss: 0.2224 - val_accuracy: 0.9190
# Epoch 89/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1586 - accuracy: 0.9400 - val_loss: 0.2202 - val_accuracy: 0.9190
# Epoch 90/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1546 - accuracy: 0.9411 - val_loss: 0.2196 - val_accuracy: 0.9190
# Epoch 91/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1567 - accuracy: 0.9440 - val_loss: 0.2202 - val_accuracy: 0.9190
# Epoch 92/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1630 - accuracy: 0.9405 - val_loss: 0.2195 - val_accuracy: 0.9211
# Epoch 93/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1566 - accuracy: 0.9446 - val_loss: 0.2182 - val_accuracy: 0.9211
# Epoch 94/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1534 - accuracy: 0.9452 - val_loss: 0.2181 - val_accuracy: 0.9211
# Epoch 95/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1660 - accuracy: 0.9388 - val_loss: 0.2169 - val_accuracy: 0.9211
# Epoch 96/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1572 - accuracy: 0.9405 - val_loss: 0.2184 - val_accuracy: 0.9211
# Epoch 97/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1434 - accuracy: 0.9498 - val_loss: 0.2168 - val_accuracy: 0.9211
# Epoch 98/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.1619 - accuracy: 0.9446 - val_loss: 0.2164 - val_accuracy: 0.9231
# Epoch 99/100
# 55/55 [==============================] - 6s 103ms/step - loss: 0.1436 - accuracy: 0.9527 - val_loss: 0.2149 - val_accuracy: 0.9211
# Epoch 100/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.1472 - accuracy: 0.9503 - val_loss: 0.2147 - val_accuracy: 0.9231

# %%
# 훈련 정확도와 손실 그래프 생성
import matplotlib.pyplot as plt 

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# %% [markdown]
# # Analysis - Training & Validation
#
# ## 불안정
# 진동폭이 확연하게 줄어들었음
#
# ## Early_Stopping
# 약 30 Epoch 이전에 Early_Stopping 되었던 다른 모델과는 달리 Early_Stopping 없이 100 Epoch까지 진행
#
# ---

# %%
test_loss, test_acc = model.evaluate(test_dataset)

print(f"test accuracy: {test_acc}")
print(f"test loss: {test_loss}")
# Out:
# 8/8 [==============================] - 1s 56ms/step - loss: 0.2381 - accuracy: 0.9237
# test accuracy: 0.9236947894096375
# test loss: 0.2381221503019333

# %% [markdown]
# # Analysis - Test
# (compared to `6. Change_Conv2D_Dense`)
# Accuracy : 96% → 92%
# Loss : 0.1188 → 0.2381
# 비교적 낮은 성능
