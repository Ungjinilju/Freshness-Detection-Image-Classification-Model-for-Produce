# %% [markdown]
# # Guide
# ## Data
# [[Google Drive] /Data/Initial/Step1.zip](https://drive.google.com/file/d/1LpnhjeBOoLH-QwbVOovCk-OpdpmIQAaZ/view?usp=sharing?usp=sharing)
# ## Code
# In [3] `base_dir` : 실제 데이터 경로로 변경 필요
#
# ---

# %% [markdown]
# # Purpose
# `1. Book` 모델의 과적합 방지
#
# ## Alternation
# (compared to) `1. Book` 모델
# Epoch = 30 → Epochs = 100
# Early_Stopping 적용 : validation_loss가 연속 5회 이상 개선이 없을 경우 학습 중단

# %%
from tensorflow import keras
from tensorflow.keras import layers
import os
# Out:
# 2024-11-20 15:20:22.431757: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
image_size = (400, 400)
batch_size = 32

# %%
# 데이터셋 로드
from tensorflow.keras.utils import image_dataset_from_directory

# 실제 데이터의 경로로 변경 필요
base_dir = "/tf/Fixed_Data/Data_Initial/Step1"

train_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'train'),
    image_size=image_size,
    batch_size=batch_size)

validation_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'validation'),
    image_size=image_size,
    batch_size=batch_size)

test_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'test'),
    image_size=image_size,
    batch_size=batch_size)
# Out:
# Found 1732 files belonging to 2 classes.
# Found 494 files belonging to 2 classes.
# Found 249 files belonging to 2 classes.
# 2024-11-20 15:20:23.873092: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 15:20:23.876339: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 15:20:23.876426: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 15:20:23.877112: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 15:20:23.877193: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 15:20:23.877264: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 15:20:23.922903: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 15:20:23.923016: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 15:20:23.923095: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 15:20:23.923161: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22209 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# 모델 레이어 구성
inputs = keras.Input(shape=(400, 400, 3))

x = layers.Rescaling(1./255)(inputs)

x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)

x = layers.Flatten()(x)

outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 199, 199, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 98, 98, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 48, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 46, 46, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 23, 23, 256)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 21, 21, 256)       590080
#
#  flatten (Flatten)           (None, 112896)            0
#
#  dense (Dense)               (None, 1)                 112897
#
# =================================================================
# Total params: 1091393 (4.16 MB)
# Trainable params: 1091393 (4.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop',
              loss="binary_crossentropy",
              metrics=['accuracy'])

# %% [markdown]
# ### Early_Stopping 설정

# %%
from tensorflow.keras.callbacks import EarlyStopping

# EarlyStopping 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss',       # 검증 손실을 기준으로 학습 중단
    patience=5,               # 성능이 개선되지 않는 에포크 수 (5회 연속 개선 없을 시 중단)
    restore_best_weights=True # 최적의 가중치 복원
)

# %% [markdown]
# ### epochs 값 변경

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,
    callbacks=[early_stopping],
    batch_size=batch_size)
# Out:
# Epoch 1/100
# 2024-11-20 15:20:25.396058: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-11-20 15:20:25.618166: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-11-20 15:20:25.618496: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f65c5641a10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-20 15:20:25.618539: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-11-20 15:20:25.621500: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-20 15:20:25.691458: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 55/55 [==============================] - 7s 72ms/step - loss: 0.8572 - accuracy: 0.5364 - val_loss: 0.6887 - val_accuracy: 0.5567
# Epoch 2/100
# 55/55 [==============================] - 4s 65ms/step - loss: 0.6752 - accuracy: 0.6085 - val_loss: 0.6005 - val_accuracy: 0.6194
# Epoch 3/100
# 55/55 [==============================] - 4s 63ms/step - loss: 0.6174 - accuracy: 0.7385 - val_loss: 1.3302 - val_accuracy: 0.6660
# Epoch 4/100
# 55/55 [==============================] - 4s 64ms/step - loss: 0.5559 - accuracy: 0.7841 - val_loss: 1.4405 - val_accuracy: 0.5202
# Epoch 5/100
# 55/55 [==============================] - 4s 64ms/step - loss: 0.4753 - accuracy: 0.8077 - val_loss: 0.3152 - val_accuracy: 0.8603
# Epoch 6/100
# 55/55 [==============================] - 4s 63ms/step - loss: 0.4931 - accuracy: 0.8383 - val_loss: 0.3371 - val_accuracy: 0.8664
# Epoch 7/100
# 55/55 [==============================] - 4s 63ms/step - loss: 0.3739 - accuracy: 0.8349 - val_loss: 0.2438 - val_accuracy: 0.9028
# Epoch 8/100
# 55/55 [==============================] - 4s 63ms/step - loss: 0.4851 - accuracy: 0.8366 - val_loss: 0.4291 - val_accuracy: 0.7045
# Epoch 9/100
# 55/55 [==============================] - 4s 63ms/step - loss: 0.3429 - accuracy: 0.8718 - val_loss: 1.2095 - val_accuracy: 0.6822
# Epoch 10/100
# 55/55 [==============================] - 4s 64ms/step - loss: 0.3449 - accuracy: 0.8499 - val_loss: 0.2511 - val_accuracy: 0.9150
# Epoch 11/100
# 55/55 [==============================] - 4s 64ms/step - loss: 0.3268 - accuracy: 0.8684 - val_loss: 0.2863 - val_accuracy: 0.8887
# Epoch 12/100
# 55/55 [==============================] - 4s 64ms/step - loss: 0.5973 - accuracy: 0.8337 - val_loss: 0.4479 - val_accuracy: 0.7530

# %%
# 훈련 정확도와 손실 그래프 생성
import matplotlib.pyplot as plt 

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# %% [markdown]
# # Analysis - Training & Validation
# ## 과적합
# 특정 Epoch에서 급격히 Validation Accuracy가 감소(Loss가 증가)하지만 그 외 Epoch은 train과 비슷한 경향을 가짐
# → 이전 모델에 비해 과적합은 줄었다고 기대할 수 있음
#
# ## 불안정
# Validation의 Accuracy, Loss 그래프의 진동 폭이 너무 큼 → 학습 중 큰 진동 폭으로 인해 과적합 전에 Early_Stopping 가능성 존재
#
# ---

# %%
test_loss, test_acc = model.evaluate(test_dataset)

print(f"test accuracy: {test_acc}")
print(f"test loss: {test_loss}")
# Out:
# 8/8 [==============================] - 1s 36ms/step - loss: 0.2962 - accuracy: 0.8635
# test accuracy: 0.8634538054466248
# test loss: 0.2961810529232025

# %% [markdown]
# # Analysis - Test
# `1. Book`의 테스트 Accuracy 83%에 비해 86%로 향상된 성능을 보이나 여전히 이진 분류 모델의 정확도로는 낮은 편
