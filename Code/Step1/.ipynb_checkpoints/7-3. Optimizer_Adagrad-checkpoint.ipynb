# %% [markdown]
# # Guide
# ## Data
# [[Google Drive] /Data/Initial/Step1.zip](https://drive.google.com/file/d/1LpnhjeBOoLH-QwbVOovCk-OpdpmIQAaZ/view?usp=sharing?usp=sharing)
# ## Code
# In [3] `base_dir` : 실제 데이터 경로로 변경 필요
#
# ---

# %% [markdown]
# # Purpose
# Validation Accuracy, Loss 그래프의 진동 폭 감소
#
# ## Alternation
# (compared to) `6. Change_Conv2D_Dense` 모델
# Optimizer : RMSprop → Adagrad

# %%
from tensorflow import keras
from tensorflow.keras import layers, optimizers
import os
# Out:
# 2024-11-21 10:49:15.125744: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
image_size = (400, 400)
batch_size = 32

# %%
# 데이터셋 로드
from tensorflow.keras.utils import image_dataset_from_directory

# 실제 데이터의 경로로 변경 필요
base_dir = "/tf/Fixed_Data/Data_Initial/Step1"

train_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'train'),
    image_size=image_size,
    batch_size=batch_size)

validation_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'validation'),
    image_size=image_size,
    batch_size=batch_size)

test_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'test'),
    image_size=image_size,
    batch_size=batch_size)
# Out:
# Found 1732 files belonging to 2 classes.
# Found 494 files belonging to 2 classes.
# 2024-11-21 10:49:16.536887: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 10:49:16.542945: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 10:49:16.543097: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 10:49:16.544063: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 10:49:16.544209: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 10:49:16.544337: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 10:49:16.616969: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 10:49:16.617080: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 10:49:16.617156: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-21 10:49:16.617220: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22209 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# Found 249 files belonging to 2 classes.

# %%
# 모델 레이어 구성
inputs = keras.Input(shape=(400, 400, 3))

x = layers.Rescaling(1./255)(inputs)

x = layers.Conv2D(filters=32, kernel_size=3)(inputs)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=256, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Dropout(0.25)(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Flatten()(x)
x = layers.Dense(256, activation = "relu")(x)
x = layers.Dropout(0.25)(x)

outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  batch_normalization (Batch  (None, 398, 398, 32)      128
#  Normalization)
#
#  re_lu (ReLU)                (None, 398, 398, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 199, 199, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 197, 197, 64)      256
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 197, 197, 64)      0
#
#  max_pooling2d_1 (MaxPoolin  (None, 98, 98, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 96, 96, 128)       512
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 96, 96, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 48, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 46, 46, 256)       295168
#
#  batch_normalization_3 (Bat  (None, 46, 46, 256)       1024
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 46, 46, 256)       0
#
#  dropout (Dropout)           (None, 46, 46, 256)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 23, 23, 256)       0
#  g2D)
#
#  flatten (Flatten)           (None, 135424)            0
#
#  dense (Dense)               (None, 256)               34668800
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 35059393 (133.74 MB)
# Trainable params: 35058433 (133.74 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________

# %% [markdown]
# ### Optimizer 변경

# %%
# 학습률 설정
# optimizer = optimizers.RMSprop(learning_rate=1e-4)
# 옵티마이저 변경
optimizer = optimizers.Adagrad(learning_rate=1e-4)

# 모델 컴파일
model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# EarlyStopping 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss',       # 검증 손실을 기준으로 학습 중단
    patience=5,               # 성능이 개선되지 않는 에포크 수 (5회 연속 개선 없을 시 중단)
    restore_best_weights=True # 최적의 가중치 복원
)

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,
    callbacks=[early_stopping],
    batch_size=batch_size)
# Out:
# Epoch 1/100
# 2024-11-21 10:49:17.677974: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-11-21 10:49:18.250201: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-11-21 10:49:18.653449: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-11-21 10:49:18.669215: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7ff804dffab0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-21 10:49:18.669236: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-11-21 10:49:18.672012: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-21 10:49:18.755057: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 55/55 [==============================] - 10s 112ms/step - loss: 0.5538 - accuracy: 0.7535 - val_loss: 0.8170 - val_accuracy: 0.4433
# Epoch 2/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.3172 - accuracy: 0.8620 - val_loss: 0.6782 - val_accuracy: 0.5263
# Epoch 3/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.2570 - accuracy: 0.8967 - val_loss: 0.4712 - val_accuracy: 0.7834
# Epoch 4/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.2186 - accuracy: 0.9117 - val_loss: 0.6449 - val_accuracy: 0.6113
# Epoch 5/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.2025 - accuracy: 0.9238 - val_loss: 0.5006 - val_accuracy: 0.7267
# Epoch 6/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.1677 - accuracy: 0.9376 - val_loss: 0.2484 - val_accuracy: 0.9089
# Epoch 7/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.1436 - accuracy: 0.9457 - val_loss: 0.2380 - val_accuracy: 0.9028
# Epoch 8/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1306 - accuracy: 0.9573 - val_loss: 0.2210 - val_accuracy: 0.9109
# Epoch 9/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.1159 - accuracy: 0.9619 - val_loss: 0.5690 - val_accuracy: 0.7348
# Epoch 10/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.1244 - accuracy: 0.9573 - val_loss: 0.2093 - val_accuracy: 0.9211
# Epoch 11/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.1008 - accuracy: 0.9711 - val_loss: 0.1983 - val_accuracy: 0.9251
# Epoch 12/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.0878 - accuracy: 0.9746 - val_loss: 0.1784 - val_accuracy: 0.9271
# Epoch 13/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.0727 - accuracy: 0.9827 - val_loss: 0.1721 - val_accuracy: 0.9332
# Epoch 14/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.0785 - accuracy: 0.9781 - val_loss: 0.1706 - val_accuracy: 0.9332
# Epoch 15/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0656 - accuracy: 0.9838 - val_loss: 0.1946 - val_accuracy: 0.9089
# Epoch 16/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0632 - accuracy: 0.9850 - val_loss: 0.1790 - val_accuracy: 0.9190
# Epoch 17/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.0661 - accuracy: 0.9838 - val_loss: 0.1662 - val_accuracy: 0.9352
# Epoch 18/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0599 - accuracy: 0.9867 - val_loss: 0.1943 - val_accuracy: 0.9170
# Epoch 19/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0673 - accuracy: 0.9850 - val_loss: 0.5284 - val_accuracy: 0.7976
# Epoch 20/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0736 - accuracy: 0.9792 - val_loss: 0.4796 - val_accuracy: 0.8057
# Epoch 21/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.0626 - accuracy: 0.9861 - val_loss: 0.1569 - val_accuracy: 0.9332
# Epoch 22/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0538 - accuracy: 0.9913 - val_loss: 0.3230 - val_accuracy: 0.8623
# Epoch 23/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0531 - accuracy: 0.9902 - val_loss: 0.1866 - val_accuracy: 0.9150
# Epoch 24/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0457 - accuracy: 0.9902 - val_loss: 0.1576 - val_accuracy: 0.9291
# Epoch 25/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.0429 - accuracy: 0.9960 - val_loss: 0.1529 - val_accuracy: 0.9372
# Epoch 26/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0403 - accuracy: 0.9931 - val_loss: 0.1536 - val_accuracy: 0.9393
# Epoch 27/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0415 - accuracy: 0.9925 - val_loss: 0.1780 - val_accuracy: 0.9190
# Epoch 28/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.0403 - accuracy: 0.9908 - val_loss: 0.1521 - val_accuracy: 0.9372
# Epoch 29/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0361 - accuracy: 0.9948 - val_loss: 0.1935 - val_accuracy: 0.9069
# Epoch 30/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.0360 - accuracy: 0.9902 - val_loss: 0.1541 - val_accuracy: 0.9352
# Epoch 31/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.0336 - accuracy: 0.9954 - val_loss: 0.1551 - val_accuracy: 0.9332
# Epoch 32/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.0311 - accuracy: 0.9948 - val_loss: 0.1493 - val_accuracy: 0.9393
# Epoch 33/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.0308 - accuracy: 0.9977 - val_loss: 0.1486 - val_accuracy: 0.9372
# Epoch 34/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0319 - accuracy: 0.9960 - val_loss: 0.1969 - val_accuracy: 0.9251
# Epoch 35/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0326 - accuracy: 0.9942 - val_loss: 0.1585 - val_accuracy: 0.9413
# Epoch 36/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.0293 - accuracy: 0.9948 - val_loss: 0.1879 - val_accuracy: 0.9312
# Epoch 37/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.0313 - accuracy: 0.9954 - val_loss: 0.1631 - val_accuracy: 0.9453
# Epoch 38/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.0273 - accuracy: 0.9971 - val_loss: 0.1586 - val_accuracy: 0.9312

# %%
# 훈련 정확도와 손실 그래프 생성
import matplotlib.pyplot as plt 

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# %% [markdown]
# # Analysis - Training & Validation
#
# ## 불안정
# 큰 향상이 보이지 않음
#
# ---

# %%
test_loss, test_acc = model.evaluate(test_dataset)

print(f"test accuracy: {test_acc}")
print(f"test loss: {test_loss}")
# Out:
# 8/8 [==============================] - 1s 56ms/step - loss: 0.1580 - accuracy: 0.9398
# test accuracy: 0.9397590160369873
# test loss: 0.1579589694738388

# %% [markdown]
# # Analysis - Test
# (compared to `6. Change_Conv2D_Dense`)
# Accuracy : 96% → 94%
# Loss : 0.1188 → 0.1580
# 약간의 성능 감소
