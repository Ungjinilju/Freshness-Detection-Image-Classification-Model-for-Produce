# %% [markdown]
# # Guide
# ## Data
# [[Google Drive] /Data/Initial/Step1.zip](https://drive.google.com/file/d/1LpnhjeBOoLH-QwbVOovCk-OpdpmIQAaZ/view?usp=sharing)
# ## Code
# In [3] `base_dir` : 실제 데이터 경로로 변경 필요
#
# ---

# %% [markdown]
# # Purpose
# 모델 성능 향상
#
# ## Alternation
# (compared to) `5. LearningRate_1e-4` 모델
# 마지막 `Conv2D` layer → `Dense(256)` layer
# ⇒ fully-connected layer → 학습 가능한 파라미터 수 증가

# %%
from tensorflow import keras
from tensorflow.keras import layers, optimizers
import os
# Out:
# 2024-11-20 16:29:13.421830: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
image_size = (400, 400)
batch_size = 32

# %%
# 데이터셋 로드
from tensorflow.keras.utils import image_dataset_from_directory

# 실제 데이터의 경로로 변경 필요
base_dir = "/tf/Fixed_Data/Data_Initial/Step1"

train_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'train'),
    image_size=image_size,
    batch_size=batch_size)

validation_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'validation'),
    image_size=image_size,
    batch_size=batch_size)

test_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'test'),
    image_size=image_size,
    batch_size=batch_size)
# Out:
# Found 1732 files belonging to 2 classes.
# Found 494 files belonging to 2 classes.
# Found 249 files belonging to 2 classes.
# 2024-11-20 16:29:14.863229: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 16:29:14.867201: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 16:29:14.867310: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 16:29:14.867968: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 16:29:14.868072: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 16:29:14.868162: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 16:29:14.911513: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 16:29:14.911624: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 16:29:14.911704: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-20 16:29:14.911799: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22209 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# ### layer 구성 변경

# %%
# 모델 레이어 구성
inputs = keras.Input(shape=(400, 400, 3))

x = layers.Rescaling(1./255)(inputs)

x = layers.Conv2D(filters=32, kernel_size=3)(inputs)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=256, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Dropout(0.25)(x)
x = layers.MaxPooling2D(pool_size=2)(x)

# x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)  # 제거

x = layers.Flatten()(x)
x = layers.Dense(256, activation = "relu")(x)  # 추가
x = layers.Dropout(0.25)(x)

outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  batch_normalization (Batch  (None, 398, 398, 32)      128
#  Normalization)
#
#  re_lu (ReLU)                (None, 398, 398, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 199, 199, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 197, 197, 64)      256
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 197, 197, 64)      0
#
#  max_pooling2d_1 (MaxPoolin  (None, 98, 98, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 96, 96, 128)       512
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 96, 96, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 48, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 46, 46, 256)       295168
#
#  batch_normalization_3 (Bat  (None, 46, 46, 256)       1024
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 46, 46, 256)       0
#
#  dropout (Dropout)           (None, 46, 46, 256)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 23, 23, 256)       0
#  g2D)
#
#  flatten (Flatten)           (None, 135424)            0
#
#  dense (Dense)               (None, 256)               34668800
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 35059393 (133.74 MB)
# Trainable params: 35058433 (133.74 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________

# %%
# 학습률 설정
optimizer = optimizers.RMSprop(learning_rate=1e-4)

# 모델 컴파일
model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# EarlyStopping 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss',       # 검증 손실을 기준으로 학습 중단
    patience=5,               # 성능이 개선되지 않는 에포크 수 (5회 연속 개선 없을 시 중단)
    restore_best_weights=True # 최적의 가중치 복원
)

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,
    callbacks=[early_stopping],
    batch_size=batch_size)
# Out:
# Epoch 1/100
# 2024-11-20 16:29:15.988171: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-11-20 16:29:16.536981: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-11-20 16:29:16.980496: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-11-20 16:29:16.994695: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7ff1567dc740 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-20 16:29:16.994729: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-11-20 16:29:16.997727: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-20 16:29:17.066646: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 55/55 [==============================] - 10s 112ms/step - loss: 3.1884 - accuracy: 0.7361 - val_loss: 1.0785 - val_accuracy: 0.4433
# Epoch 2/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.4068 - accuracy: 0.8528 - val_loss: 0.6417 - val_accuracy: 0.7166
# Epoch 3/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2622 - accuracy: 0.9024 - val_loss: 0.4134 - val_accuracy: 0.8138
# Epoch 4/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2563 - accuracy: 0.9059 - val_loss: 0.2932 - val_accuracy: 0.8583
# Epoch 5/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.2172 - accuracy: 0.9365 - val_loss: 0.7467 - val_accuracy: 0.6073
# Epoch 6/100
# 55/55 [==============================] - 6s 102ms/step - loss: 0.2114 - accuracy: 0.9232 - val_loss: 0.1226 - val_accuracy: 0.9514
# Epoch 7/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.1753 - accuracy: 0.9382 - val_loss: 0.1239 - val_accuracy: 0.9575
# Epoch 8/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1344 - accuracy: 0.9527 - val_loss: 0.1622 - val_accuracy: 0.9312
# Epoch 9/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.1008 - accuracy: 0.9694 - val_loss: 0.6096 - val_accuracy: 0.8340
# Epoch 10/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.1097 - accuracy: 0.9654 - val_loss: 0.2716 - val_accuracy: 0.8907
# Epoch 11/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.0728 - accuracy: 0.9746 - val_loss: 0.0889 - val_accuracy: 0.9636
# Epoch 12/100
# 55/55 [==============================] - 6s 101ms/step - loss: 0.0631 - accuracy: 0.9758 - val_loss: 0.7421 - val_accuracy: 0.7510
# Epoch 13/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.0606 - accuracy: 0.9821 - val_loss: 0.1363 - val_accuracy: 0.9433
# Epoch 14/100
# 55/55 [==============================] - 6s 99ms/step - loss: 0.0482 - accuracy: 0.9792 - val_loss: 0.1039 - val_accuracy: 0.9656
# Epoch 15/100
# 55/55 [==============================] - 6s 100ms/step - loss: 0.0692 - accuracy: 0.9781 - val_loss: 0.1209 - val_accuracy: 0.9636
# Epoch 16/100
# 55/55 [==============================] - 6s 103ms/step - loss: 0.0440 - accuracy: 0.9861 - val_loss: 0.1340 - val_accuracy: 0.9636

# %%
# 훈련 정확도와 손실 그래프 생성
import matplotlib.pyplot as plt 

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# %% [markdown]
# # Analysis - Training & Validation
# ## 과적합
# 특정 Epoch에서 급격히 Validation Accuracy가 감소(Loss가 증가)하지만 그 외 Epoch은 train과 비슷한 경향을 가짐
# 이전 모델에 비해 train과 validation 그래프의 차이 감소
#
# ## 불안정
# 진동 없이 안정적인 형태였던 이전 모델과 달리 다시 진동 발생
#
# ---

# %%
test_loss, test_acc = model.evaluate(test_dataset)

print(f"test accuracy: {test_acc}")
print(f"test loss: {test_loss}")
# Out:
# 8/8 [==============================] - 1s 55ms/step - loss: 0.1188 - accuracy: 0.9639
# test accuracy: 0.9638554453849792
# test loss: 0.11878196150064468

# %% [markdown]
# # Analysis - Test
# (compared to `5. LearningRate_1e-4`)
# Accuracy : 93% → 96%
# Loss : 0.1676 → 0.1188
# 훈련 그래프의 진동 형태로 인한 우려와 달리 성능은 향상됨
