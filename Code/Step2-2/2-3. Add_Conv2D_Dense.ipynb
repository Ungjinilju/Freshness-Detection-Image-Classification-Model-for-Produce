# %% [markdown]
# # Guide
# ## Data
# [[Google Drive] /Data/Final/Step2-2.zip](https://drive.google.com/file/d/19ARNrbgWSn-Wi5k7uXKehJnzmvbIRThv/view?usp=sharing)
# ## Code
# In [3] `base_dir` : 실제 데이터 경로로 변경 필요
#
# ---

# %% [markdown]
# # Purpose
# 모델 성능 향상
#
# ## Alternation
# (compared to `1. Step2-1`)
# `Conv2D(256)` layer, `Dense(256)` layer 추가

# %%
from tensorflow import keras
from tensorflow.keras import layers, optimizers
import os
# Out:
# 2024-11-23 13:34:11.391000: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
image_size = (400, 400)
batch_size = 32

# %%
# 데이터셋 로드
from tensorflow.keras.utils import image_dataset_from_directory

# 실제 데이터의 경로로 변경 필요
base_dir = "/tf/Fixed_Data/Data_Final/Step2-2" 

train_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'train'),
    image_size=image_size,
    batch_size=batch_size)

validation_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'validation'),
    image_size=image_size,
    batch_size=batch_size)

test_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'test'),
    image_size=image_size,
    batch_size=batch_size)
# Out:
# Found 11340 files belonging to 18 classes.
# Found 3240 files belonging to 18 classes.
# Found 1620 files belonging to 18 classes.
# 2024-11-23 13:34:13.077905: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 13:34:13.081216: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 13:34:13.081302: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 13:34:13.081988: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 13:34:13.082066: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 13:34:13.082135: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 13:34:13.142349: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 13:34:13.142460: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 13:34:13.142538: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 13:34:13.142604: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22207 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# ### Conv(256), Dense(256) layer 추가

# %%
# 모델 레이어 구성
inputs = keras.Input(shape=(400, 400, 3))

x = layers.Rescaling(1./255)(inputs)

x = layers.Conv2D(filters=32, kernel_size=3)(inputs)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=256, kernel_size=3)(x)
x = layers.Conv2D(filters=256, kernel_size=3)(x)   # 추가
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=512, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Dropout(0.3)(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Flatten()(x)
x = layers.Dense(512, activation = "relu")(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(256, activation = "relu")(x)   # 추가

outputs = layers.Dense(18, activation="softmax")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  batch_normalization (Batch  (None, 398, 398, 32)      128
#  Normalization)
#
#  re_lu (ReLU)                (None, 398, 398, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 199, 199, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 197, 197, 64)      256
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 197, 197, 64)      0
#
#  max_pooling2d_1 (MaxPoolin  (None, 98, 98, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 96, 96, 128)       512
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 96, 96, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 48, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 46, 46, 256)       295168
#
#  conv2d_4 (Conv2D)           (None, 44, 44, 256)       590080
#
#  batch_normalization_3 (Bat  (None, 44, 44, 256)       1024
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 44, 44, 256)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 22, 22, 256)       0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 20, 20, 512)       1180160
#
#  batch_normalization_4 (Bat  (None, 20, 20, 512)       2048
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 20, 20, 512)       0
#
#  dropout (Dropout)           (None, 20, 20, 512)       0
#
#  max_pooling2d_4 (MaxPoolin  (None, 10, 10, 512)       0
#  g2D)
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 512)               26214912
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 18)                4626
#
# =================================================================
# Total params: 28513490 (108.77 MB)
# Trainable params: 28511506 (108.76 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %%
# 학습률 및 옵티마이저 설정
optimizer = optimizers.RMSprop(learning_rate=1e-4)

# 모델 컴파일
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# EarlyStopping 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss',       # 검증 손실을 기준으로 학습 중단
    patience=5,               # 성능이 개선되지 않는 에포크 수 (5회 연속 개선 없을 시 중단)
    restore_best_weights=True # 최적의 가중치 복원
)

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,
    callbacks=[early_stopping],
    batch_size=batch_size)
# Out:
# Epoch 1/100
# 2024-11-23 13:34:14.546043: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-11-23 13:34:15.071149: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-11-23 13:34:15.597368: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-11-23 13:34:15.615887: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x83e8260 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-23 13:34:15.615909: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-11-23 13:34:15.619015: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-23 13:34:15.690302: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 355/355 [==============================] - 42s 105ms/step - loss: 1.9248 - accuracy: 0.4698 - val_loss: 1.4979 - val_accuracy: 0.5506
# Epoch 2/100
# 355/355 [==============================] - 37s 102ms/step - loss: 1.2007 - accuracy: 0.6260 - val_loss: 0.9755 - val_accuracy: 0.6849
# Epoch 3/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.9810 - accuracy: 0.6911 - val_loss: 1.0843 - val_accuracy: 0.6509
# Epoch 4/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.8692 - accuracy: 0.7253 - val_loss: 0.8772 - val_accuracy: 0.7247
# Epoch 5/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.7893 - accuracy: 0.7508 - val_loss: 0.8638 - val_accuracy: 0.7219
# Epoch 6/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.7018 - accuracy: 0.7707 - val_loss: 0.7860 - val_accuracy: 0.7688
# Epoch 7/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.6445 - accuracy: 0.7900 - val_loss: 0.7555 - val_accuracy: 0.7540
# Epoch 8/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.6001 - accuracy: 0.8078 - val_loss: 0.7549 - val_accuracy: 0.7645
# Epoch 9/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.5485 - accuracy: 0.8264 - val_loss: 0.5670 - val_accuracy: 0.8235
# Epoch 10/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.5136 - accuracy: 0.8368 - val_loss: 0.6555 - val_accuracy: 0.7957
# Epoch 11/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.4734 - accuracy: 0.8450 - val_loss: 0.7100 - val_accuracy: 0.7781
# Epoch 12/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.4400 - accuracy: 0.8556 - val_loss: 0.6999 - val_accuracy: 0.7765
# Epoch 13/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.4211 - accuracy: 0.8660 - val_loss: 0.6695 - val_accuracy: 0.7966
# Epoch 14/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.3724 - accuracy: 0.8772 - val_loss: 0.5556 - val_accuracy: 0.8253
# Epoch 15/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.3738 - accuracy: 0.8787 - val_loss: 0.7913 - val_accuracy: 0.7756
# Epoch 16/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.3403 - accuracy: 0.8891 - val_loss: 0.5743 - val_accuracy: 0.8191
# Epoch 17/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.3289 - accuracy: 0.8914 - val_loss: 0.6202 - val_accuracy: 0.8065
# Epoch 18/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.3105 - accuracy: 0.8986 - val_loss: 0.6791 - val_accuracy: 0.8080
# Epoch 19/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.3060 - accuracy: 0.9011 - val_loss: 0.5309 - val_accuracy: 0.8423
# Epoch 20/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.2818 - accuracy: 0.9108 - val_loss: 0.5186 - val_accuracy: 0.8398
# Epoch 21/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.2724 - accuracy: 0.9102 - val_loss: 0.5407 - val_accuracy: 0.8568
# Epoch 22/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.2591 - accuracy: 0.9172 - val_loss: 0.5642 - val_accuracy: 0.8173
# Epoch 23/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.2382 - accuracy: 0.9223 - val_loss: 0.5729 - val_accuracy: 0.8241
# Epoch 24/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.2355 - accuracy: 0.9256 - val_loss: 0.4087 - val_accuracy: 0.8793
# Epoch 25/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.2233 - accuracy: 0.9277 - val_loss: 0.5410 - val_accuracy: 0.8441
# Epoch 26/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.2267 - accuracy: 0.9286 - val_loss: 0.4657 - val_accuracy: 0.8738
# Epoch 27/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.2061 - accuracy: 0.9328 - val_loss: 0.6169 - val_accuracy: 0.8429
# Epoch 28/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.2119 - accuracy: 0.9333 - val_loss: 0.4693 - val_accuracy: 0.8602
# Epoch 29/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.2011 - accuracy: 0.9397 - val_loss: 0.4793 - val_accuracy: 0.8673

# %%
# 훈련 정확도와 손실 그래프 생성
import matplotlib.pyplot as plt 

acc = history.history['accuracy'][:-5]           
val_acc = history.history['val_accuracy'][:-5]   
loss = history.history['loss'][:-5]              
val_loss = history.history['val_loss'][:-5]  
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# %% [markdown]
# # Analysis - Training & Validation
# ## 불안정
# 전체적으로 validation 그래프가 진동하는 형태
# 그러나 training과 validation 그래프가 비슷하게 진행
#
# ---

# %%
test_loss, test_acc = model.evaluate(test_dataset)

print(f"test accuracy: {test_acc}")
print(f"test loss: {test_loss}")
# Out:
# 51/51 [==============================] - 3s 45ms/step - loss: 0.4432 - accuracy: 0.8704
# test accuracy: 0.8703703880310059
# test loss: 0.44323402643203735

# %% [markdown]
# # Analysis - Test
# - (compared to `1. Step2-1`)
# Accuracy : 85.7%% → 87.0%
# Loss : 0.4680 → 0.4432
# 성능 소폭 향상
#
# <br>
#
# - (compared to `2-1. Add_Conv2D`, `2-2. Add_Dense`)
# 현재 모델이 유일하게 `1. Step2-1`모델에서의 성능 향상이 있었음
# ⇒ 현재 모델 선정
