# %% [markdown]
# # Guide
# ## Data
# [[Google Drive] /Data/Final/Step2-2.zip](https://drive.google.com/file/d/19ARNrbgWSn-Wi5k7uXKehJnzmvbIRThv/view?usp=sharing)
# ## Code
# In [3] `base_dir` : 실제 데이터 경로로 변경 필요
#
# ---

# %% [markdown]
# # Purpose
# 모델 성능 향상
#
# ## Alternation
# (compared to `1. Step2-1`)
# `Conv2D(256)` layer 추가

# %%
from tensorflow import keras
from tensorflow.keras import layers, optimizers
import os
# Out:
# 2024-11-23 11:23:55.253580: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
image_size = (400, 400)
batch_size = 32

# %%
# 데이터셋 로드
from tensorflow.keras.utils import image_dataset_from_directory

# 실제 데이터의 경로로 변경 필요
base_dir = "/tf/Fixed_Data/Data_Final/Step2-2"

train_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'train'),
    image_size=image_size,
    batch_size=batch_size)

validation_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'validation'),
    image_size=image_size,
    batch_size=batch_size)

test_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'test'),
    image_size=image_size,
    batch_size=batch_size)
# Out:
# Found 11340 files belonging to 18 classes.
# Found 3240 files belonging to 18 classes.
# Found 1620 files belonging to 18 classes.
# 2024-11-23 11:23:57.132295: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 11:23:57.135492: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 11:23:57.135578: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 11:23:57.136321: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 11:23:57.136401: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 11:23:57.136471: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 11:23:57.258877: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 11:23:57.258989: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 11:23:57.259066: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-23 11:23:57.259130: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22207 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# ### Conv2D(256) layer 추가

# %%
# 모델 레이어 구성
inputs = keras.Input(shape=(400, 400, 3))

x = layers.Rescaling(1./255)(inputs)

x = layers.Conv2D(filters=32, kernel_size=3)(inputs)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=64, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=256, kernel_size=3)(x)
x = layers.Conv2D(filters=256, kernel_size=3)(x)   # 추가
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Conv2D(filters=512, kernel_size=3)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.Dropout(0.3)(x)
x = layers.MaxPooling2D(pool_size=2)(x)

x = layers.Flatten()(x)
x = layers.Dense(512, activation = "relu")(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(18, activation="softmax")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  batch_normalization (Batch  (None, 398, 398, 32)      128
#  Normalization)
#
#  re_lu (ReLU)                (None, 398, 398, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 199, 199, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 64)      18496
#
#  batch_normalization_1 (Bat  (None, 197, 197, 64)      256
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 197, 197, 64)      0
#
#  max_pooling2d_1 (MaxPoolin  (None, 98, 98, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 96, 96, 128)       512
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 96, 96, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 48, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 46, 46, 256)       295168
#
#  conv2d_4 (Conv2D)           (None, 44, 44, 256)       590080
#
#  batch_normalization_3 (Bat  (None, 44, 44, 256)       1024
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 44, 44, 256)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 22, 22, 256)       0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 20, 20, 512)       1180160
#
#  batch_normalization_4 (Bat  (None, 20, 20, 512)       2048
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 20, 20, 512)       0
#
#  dropout (Dropout)           (None, 20, 20, 512)       0
#
#  max_pooling2d_4 (MaxPoolin  (None, 10, 10, 512)       0
#  g2D)
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 512)               26214912
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 18)                9234
#
# =================================================================
# Total params: 28386770 (108.29 MB)
# Trainable params: 28384786 (108.28 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %%
# 학습률 및 옵티마이저 설정
optimizer = optimizers.RMSprop(learning_rate=1e-4)

# 모델 컴파일
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# EarlyStopping 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss',       # 검증 손실을 기준으로 학습 중단
    patience=5,               # 성능이 개선되지 않는 에포크 수 (5회 연속 개선 없을 시 중단)
    restore_best_weights=True # 최적의 가중치 복원
)

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,
    callbacks=[early_stopping],
    batch_size=batch_size)
# Out:
# Epoch 1/100
# 2024-11-23 11:23:58.608691: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-11-23 11:23:59.156482: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-11-23 11:23:59.690500: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-11-23 11:23:59.708882: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x8685720 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-23 11:23:59.708905: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-11-23 11:23:59.711994: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-23 11:23:59.783214: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 355/355 [==============================] - 42s 105ms/step - loss: 2.1105 - accuracy: 0.4794 - val_loss: 1.1775 - val_accuracy: 0.6204
# Epoch 2/100
# 355/355 [==============================] - 37s 102ms/step - loss: 1.1200 - accuracy: 0.6430 - val_loss: 1.1642 - val_accuracy: 0.6571
# Epoch 3/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.9204 - accuracy: 0.7101 - val_loss: 0.7975 - val_accuracy: 0.7562
# Epoch 4/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.7952 - accuracy: 0.7468 - val_loss: 0.9898 - val_accuracy: 0.7120
# Epoch 5/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.6956 - accuracy: 0.7780 - val_loss: 0.5904 - val_accuracy: 0.8099
# Epoch 6/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.6124 - accuracy: 0.8020 - val_loss: 0.7379 - val_accuracy: 0.7855
# Epoch 7/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.5658 - accuracy: 0.8208 - val_loss: 0.9160 - val_accuracy: 0.7299
# Epoch 8/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.5049 - accuracy: 0.8369 - val_loss: 0.6661 - val_accuracy: 0.7898
# Epoch 9/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.4595 - accuracy: 0.8482 - val_loss: 0.5288 - val_accuracy: 0.8293
# Epoch 10/100
# 355/355 [==============================] - 36s 101ms/step - loss: 0.4364 - accuracy: 0.8588 - val_loss: 0.5856 - val_accuracy: 0.8022
# Epoch 11/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.3955 - accuracy: 0.8686 - val_loss: 0.4843 - val_accuracy: 0.8475
# Epoch 12/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.3630 - accuracy: 0.8830 - val_loss: 0.5702 - val_accuracy: 0.8275
# Epoch 13/100
# 355/355 [==============================] - 36s 101ms/step - loss: 0.3348 - accuracy: 0.8916 - val_loss: 0.8674 - val_accuracy: 0.8015
# Epoch 14/100
# 355/355 [==============================] - 36s 102ms/step - loss: 0.3218 - accuracy: 0.8983 - val_loss: 0.7090 - val_accuracy: 0.7920
# Epoch 15/100
# 355/355 [==============================] - 36s 101ms/step - loss: 0.3074 - accuracy: 0.8985 - val_loss: 0.8025 - val_accuracy: 0.7753
# Epoch 16/100
# 355/355 [==============================] - 37s 102ms/step - loss: 0.2839 - accuracy: 0.9098 - val_loss: 0.6759 - val_accuracy: 0.8222

# %%
# 훈련 정확도와 손실 그래프 생성
import matplotlib.pyplot as plt 

acc = history.history['accuracy'][:-5]         
val_acc = history.history['val_accuracy'][:-5] 
loss = history.history['loss'][:-5]              
val_loss = history.history['val_loss'][:-5]    
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# %% [markdown]
# # Analysis - Training & Validation
# ## 불안정
# 전체적으로 validation 그래프가 진동하는 형태
# 그러나 training과 validation 그래프가 비슷하게 진행
#
# ---

# %%
test_loss, test_acc = model.evaluate(test_dataset)

print(f"test accuracy: {test_acc}")
print(f"test loss: {test_loss}")
# Out:
# 51/51 [==============================] - 3s 47ms/step - loss: 0.5221 - accuracy: 0.8309
# test accuracy: 0.8308641910552979
# test loss: 0.522144615650177

# %% [markdown]
# # Analysis - Test
# (compared to `1. Step2-1`)
# Accuracy : 85.7%% → 83.1%
# Loss : 0.4680 → 0.5221
# 성능 감소
